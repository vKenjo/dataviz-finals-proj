# %% [markdown]
# ---
#
# # 1. Project Background
#
# ## The Global Poverty Challenge
#
# Extreme poverty remains one of humanity's most pressing challenges. Despite remarkable economic growth and technological advancement, approximately **700 million people**—nearly 9% of the global population—still live on less than $2.15 per day as of 2023 (World Bank, 2023).
#
# ## UN Sustainable Development Goal 1: No Poverty
#
# The United Nations' Sustainable Development Goal 1 aims to **"end poverty in all its forms everywhere" by 2030**. This ambitious target encompasses:
#
# - Eradicating extreme poverty (living on <$2.15/day)
# - Reducing poverty by half according to national definitions
# - Implementing social protection systems
# - Ensuring equal rights to economic resources and basic services
#
# ## Historical Context
#
# The past three decades have witnessed unprecedented poverty reduction:
# - **1990:** ~36% of the global population lived in extreme poverty
# - **2023:** ~9% live in extreme poverty
# - **Result:** Over 1.2 billion people lifted out of poverty
#
# However, progress has been uneven:
# - **East Asia:** Reduced from 66% to <1% (driven by China)
# - **Sub-Saharan Africa:** Remains above 40% in many countries
#
# ## Project Significance
#
# This project contributes by:
# 1. Providing comprehensive visual analysis of 33 years of global poverty data
# 2. Identifying correlations between poverty and development indicators
# 3. Comparing successful and challenging cases
# 4. Generating evidence-based policy recommendations

# %% [markdown]
# ---
#
# # 2. Statement of the Problem
#
# ## Primary Research Question
#
# **"How do poverty rates in Southeast Asian countries, particularly the Philippines, compare to global trends from 1990-2023, and what development indicators explain the Philippines' persistent poverty challenge despite economic growth?"**
#
# ## Specific Research Questions
#
# ### Tier 1: Global Level Questions
#
# 1. **RQ1.1**: How has extreme poverty evolved globally from 1990-2023?
# 2. **RQ1.2**: Which world regions achieved the fastest poverty reduction rates?
# 3. **RQ1.3**: What is the global benchmark for successful poverty reduction?
# 4. **RQ1.4**: How do development indicators correlate with poverty reduction globally?
#
# ### Tier 2: Southeast Asia Regional Questions
#
# 5. **RQ2.1**: How do SEA countries compare to each other in poverty reduction trajectories?
# 6. **RQ2.2**: Which SEA country has been most/least successful in reducing poverty?
# 7. **RQ2.3**: How does Southeast Asia as a region perform relative to global averages?
# 8. **RQ2.4**: What development patterns distinguish successful SEA countries (Vietnam, Malaysia) from others?
#
# ### Tier 3: Philippines-Specific Questions
#
# 9. **RQ3.1**: Why does the Philippines have the highest poverty rate among ASEAN-6 economies?
# 10. **RQ3.2**: How has the Philippines' poverty evolved compared to similar-GDP countries?
# 11. **RQ3.3**: What development indicators (education, health, infrastructure) correlate most strongly with Philippine poverty?
# 12. **RQ3.4**: What explains the "growth elasticity puzzle" - why hasn't 6-7% annual GDP growth reduced poverty proportionally?
#
# ## Objectives by Analysis Tier
#
# | Tier | Objective | Description | Key Deliverable |
# |------|-----------|-------------|-----------------|
# | **Global** | Establish Baseline | Analyze worldwide poverty trends 1990-2023 | Global poverty reduction rate & regional rankings |
# | **Global** | Identify Patterns | Determine which regions/factors drove success | Correlation analysis of global indicators |
# | **SEA** | Regional Comparison | Compare all Southeast Asian countries' poverty trajectories | SEA country ranking & trend visualizations |
# | **SEA** | Best Practice Analysis | Identify what Vietnam/Malaysia did differently | Policy insights from successful cases |
# | **Philippines** | Deep-Dive Analysis | Detailed examination of Philippine poverty patterns | Philippine poverty profile & trends |
# | **Philippines** | Comparative Positioning | Compare Philippines to SEA peers and similar economies | Gap analysis vs. regional benchmarks |
# | **Philippines** | Correlation Analysis | Link poverty to education, health, infrastructure, economic indicators | Multi-dimensional correlation matrix |
# | **Philippines** | Policy Insights | Generate evidence-based recommendations | Actionable recommendations for poverty reduction |
#
# ## Scope
#
# ### Geographic Coverage
#
# **Global Comparison Group** (for Tier 1 context):
# - All countries with available data, grouped by World Bank regions
# - Focus on regional aggregates and representative countries
#
# **Southeast Asia Focus** (Tier 2 primary analysis):
# - **ASEAN-6**: Philippines, Indonesia, Thailand, Vietnam, Malaysia, Singapore
# - **Other SEA**: Myanmar, Laos, Cambodia, Brunei (where data available)
# - **Total**: ~10 Southeast Asian countries
#
# **Philippines** (Tier 3 deep-dive):
# - Complete time series: 1990-2023
# - Multi-indicator analysis (10+ development indicators)
# - Peer comparison with Vietnam, Indonesia, Thailand
#
# ### Temporal Coverage
#
# - **Primary Period**: 1990-2023 (33 years)
# - **Key Periods**:
#   - **1990-1997**: Pre-Asian Financial Crisis
#   - **1997-2000**: Asian Financial Crisis impact
#   - **2000-2008**: Recovery and growth
#   - **2008-2010**: Global Financial Crisis
#   - **2010-2019**: Sustained growth period
#   - **2020-2023**: COVID-19 pandemic and recovery
#
# ### Indicators Analyzed
#
# **Primary Indicator:**
# - Poverty headcount ratio at $2.15/day (2017 PPP) - % of population
#
# **Development Indicators** (for correlation analysis):
# - **Education**: Primary enrollment, secondary enrollment, literacy rates
# - **Health**: Life expectancy, maternal mortality
# - **Infrastructure**: Electricity access, water access, sanitation
# - **Economic**: GDP per capita, unemployment rate
# - **Demographic**: Population, urban population %
#
# ## Limitations
#
# 1. **Data Gaps**:
#    - Not all countries have continuous annual data
#    - Philippines has gaps in certain years for some indicators
#    - Some SEA countries lack consistent poverty measurement
#
# 2. **Measurement Consistency**:
#    - Poverty measurement methodologies vary across countries
#    - PPP (Purchasing Power Parity) calculations updated periodically
#    - International poverty line ($2.15/day) may not reflect local realities
#
# 3. **Sub-national Variation**:
#    - Country-level data masks regional disparities within countries
#    - Philippines has significant urban-rural and regional poverty gaps
#    - Island geography creates unique challenges not captured in national data
#
# 4. **Recent Events**:
#    - COVID-19 impact (2020-2023) may not be fully reflected in latest data
#    - Some countries have reporting lags of 1-2 years
#
# 5. **Causation vs. Correlation**:
#    - Statistical correlations don't necessarily prove causation
#    - Multiple factors interact in complex ways to affect poverty
#
# 6. **Comparative Limitations**:
#    - Philippines' unique geography (archipelago) and demographics differ from mainland SEA countries
#    - Historical, political, and institutional contexts vary significantly across countries

# %% [markdown]
# ---
#
# # 3. Background on the Dataset
#
# ## World Development Indicators (WDI)
#
# **Source:** World Bank Open Data (https://data.worldbank.org/indicator)
#
# **Dataset Characteristics:**
# - **Time Span:** 1960-present (we focus on 1990-2023)
# - **Coverage:** ~200+ countries and territories
# - **Indicators:** 1,400+ indicators across multiple themes
# - **Structure:** Long format (one row per country-indicator-year)
# - **Columns:** Country Name, Country Code, Indicator Name, Indicator Code, Year, Value
#
# ## Indicators Used in This Study
#
# ### Primary Poverty Indicator
# 1. **SI.POV.DDAY** - Poverty headcount ratio at $2.15/day (% of population)
#
# ### Education Indicators
# 2. **SE.PRM.NENR** - Primary school enrollment rate (% net)
# 3. **SE.SEC.ENRR** - Secondary school enrollment rate (% gross)
# 4. **SE.ADT.LITR.ZS** - Adult literacy rate (% ages 15+)
#
# ### Health Indicators
# 5. **SH.STA.MMRT** - Maternal mortality ratio (per 100,000 live births)
# 6. **SP.DYN.LE00.IN** - Life expectancy at birth (years)
#
# ### Infrastructure Indicators
# 7. **EG.ELC.ACCS.ZS** - Access to electricity (% of population)
# 8. **SH.H2O.SMDW.ZS** - Access to safely managed drinking water (%)
# 9. **SH.STA.SMSS.ZS** - Access to safely managed sanitation (%)
#
# ### Economic Indicators
# 10. **NY.GDP.PCAP.CD** - GDP per capita (current US$)
# 11. **SL.UEM.TOTL.ZS** - Unemployment rate (% of labor force)
#
# ### Demographic
# 12. **SP.POP.TOTL** - Total population
# 13. **SP.URB.TOTL.IN.ZS** - Urban population (% of total)
#
# ## Access Methods
# - World Bank API (`wbdata` Python library)
# - Bulk CSV downloads
# - Kaggle datasets

# %% [markdown]
# ---
#
# # 4. Literature Review
#
# ## Key Sources and Prior Research
#
# ### 1. World Bank Poverty and Shared Prosperity Reports (2020-2024)
# **Relevance**: Provides global poverty trends and methodology
# - Documents global poverty reduction from 36% (1990) to 9% (2023)
# - Highlights COVID-19's impact: first increase in extreme poverty in a generation (2020)
# - Provides standardized measurement methodology for international poverty line ($2.15/day)
# - **Gap**: Limited focus on Philippines-specific challenges within SEA context
#
# ### 2. UN SDG Progress Reports (2015-2024)
# **Relevance**: Official SDG 1 tracking and country assessments
# - Tracks progress toward "ending extreme poverty by 2030"
# - Country-level progress assessments and best practices
# - Identifies success stories (Vietnam, China) and challenges (Sub-Saharan Africa)
# - **Gap**: Aggregates regional data, doesn't deeply compare individual SEA countries
#
# ### 3. Our World in Data - "Global Extreme Poverty" (Roser & Ortiz-Ospina, 2023)
# **Relevance**: Long-term historical perspective and interactive visualizations
# - Interactive visualizations of 200+ years of poverty trends
# - Data quality discussions and methodology transparency
# - Country-level comparisons with downloadable datasets
# - **Gap**: Lacks specific Southeast Asia regional analysis and Philippines deep-dive
#
# ### 4. Academic Research on Southeast Asian Poverty
#
# **"Vietnam's Success in Poverty Reduction"** (World Bank, 2020)
# - Analyzed Vietnam's reduction from 50% (1992) to <2% (2018) poverty rate
# - Identified key factors: agricultural reforms, rural infrastructure, education investment
# - **Relevance**: Provides model for what successful poverty reduction looks like in SEA context
#
# **"The Philippines Poverty Puzzle"** (ADB, 2019)
# - Examines why Philippines' poverty remains high despite economic growth
# - Identifies structural issues: inequality, weak job creation, limited rural development
# - **Relevance**: Directly addresses our Tier 3 research question
#
# **"Education and Poverty: Systematic Review"** (UNESCO, 2021)
# - Meta-analysis of 200+ studies on education-poverty relationships
# - Strong correlation (r = -0.7 to -0.8) between primary enrollment and poverty reduction
# - **Relevance**: Supports our correlation analysis methodology
#
# **"Infrastructure and Poverty Reduction in Asia"** (Asian Development Bank, 2018)
# - Demonstrates electricity access, roads, and sanitation correlate with poverty reduction
# - Case studies include Philippines, Vietnam, Indonesia
# - **Relevance**: Informs our infrastructure indicator selection
#
# ### 5. Existing Dashboards and Visualizations
#
# **World Bank Poverty & Equity Data Portal**
# - Interactive country profiles and regional comparisons
# - **Strength**: Comprehensive indicator coverage
# - **Gap**: Limited comparative analysis tools; doesn't highlight Philippines paradox
#
# **Gapminder Poverty Visualizations**
# - Animated bubble charts showing poverty vs. income over time
# - **Strength**: Engaging time-series visualizations
# - **Gap**: Doesn't focus specifically on SEA or Philippines
#
# **UNDP Human Development Index Dashboards**
# - Composite index combining income, education, health
# - **Strength**: Holistic development view
# - **Gap**: Different focus than extreme poverty; less granular
#
# ### 6. Philippines-Specific Studies
#
# **Philippine Statistics Authority (PSA) - Poverty Statistics**
# - Official national poverty data using Philippine poverty line
# - **Limitation**: Uses different threshold ($2.15/day international vs. Philippine national line)
#
# **"Inclusive Growth in the Philippines"** (World Bank, 2021)
# - Analyzes why growth hasn't been pro-poor
# - Identifies labor market issues, regional inequality, education quality gaps
#
# ## Gaps in Existing Literature
#
# While existing works provide excellent foundation, this project addresses several gaps:
#
# 1. **Lack of Three-Tier Comparative Framework**:
#    - No study systematically compares Global → SEA → Philippines poverty patterns
#    - Our approach provides context at each level
#
# 2. **Limited SEA Country Comparisons**:
#    - Most studies compare regions (East Asia, Southeast Asia) not individual SEA countries
#    - We directly compare Philippines to Vietnam, Indonesia, Thailand, Malaysia
#
# 3. **Insufficient Philippines Deep-Dive**:
#    - Philippines often grouped with "middle-income Asia" despite unique challenges
#    - Our Tier 3 analysis focuses specifically on Philippines' poverty puzzle
#
# 4. **Static vs. Dynamic Analysis**:
#    - Many studies show current snapshots; we analyze 33-year trajectories
#    - Visualizations will show poverty transitions over time
#
# 5. **Limited Correlation Analysis in SEA Context**:
#    - Few studies examine which specific indicators correlate with poverty in SEA countries
#    - Our multi-dimensional correlation analysis fills this gap
#
# ## Our Contribution
#
# This project builds on prior research by:
#
# 1. **Three-Tier Framework**: Systematic Global → SEA → Philippines comparative approach
# 2. **Updated Data**: Through 2023, including post-COVID recovery period
# 3. **Visual Analytics**: Interactive choropleth maps, time-series trends, scatter plots, correlation heatmaps
# 4. **SEA-Specific Insights**: Direct comparison of Philippines with successful SEA neighbors
# 5. **Policy-Relevant**: Identifies specific indicators where Philippines lags and could improve

# %% [markdown]
# ---
#
# # 5. Methodology
#
# ## 5a. Dataset Specification
#
# We use 13 World Development Indicators (listed in Section 3) chosen for their:
# - **Relevance** to SDG 1 and poverty reduction
# - **Data availability** across countries and years
# - **Theoretical grounding** in development economics
#
# Each indicator represents a dimension of development that affects poverty:
# - **Education** creates opportunities
# - **Health** enables productivity
# - **Infrastructure** supports economic activity
# - **Economic growth** provides resources for poverty alleviation

# %% [markdown]
# ## 5b. Data Preparation
#
# ### Step 1: Import Libraries and Setup

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
from pathlib import Path
from datetime import datetime

warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

# Create directories
FIGURES_DIR = Path('figures')
DATA_DIR = Path('data')
FIGURES_DIR.mkdir(exist_ok=True)
DATA_DIR.mkdir(exist_ok=True)

print("✓ Libraries imported successfully")
print(f"✓ Figures will be saved to: {FIGURES_DIR}")
print(f"✓ Data directory: {DATA_DIR}")
# Out:
# ✓ Libraries imported successfully
# ✓ Figures will be saved to: figures
# ✓ Data directory: data

# %% [markdown]
# ### Step 2: Load or Download Data
#
# We'll try to load existing data first, otherwise we'll need to download from World Bank API.

# %%
# Check if data file exists
data_file = DATA_DIR / 'data.csv'

if data_file.exists():
    print(f"Loading existing data from {data_file}...")
    df = pd.read_csv(data_file)
    print(f"✓ Loaded {len(df):,} records")
    print(f"✓ Columns: {list(df.columns)}")
else:
    print("No existing data file found.")

# Display basic info
print("\nDataset Overview:")
print(f"Shape: {df.shape}")
print(f"\nFirst few rows:")
df.head()
# Out:
# Loading existing data from data\data.csv...
# ✓ Loaded 17,195 records
# ✓ Columns: ['country', 'country_code', 'year', 'electricity_access', 'gdp_per_capita', 'life_expectancy', 'population', 'poverty_headcount', 'primary_enrollment', 'secondary_enrollment']
#
# Dataset Overview:
# Shape: (17195, 10)
#
# First few rows:
#        country country_code  year  electricity_access  gdp_per_capita  \
# 0  Afghanistan          AFG  1960                 NaN             NaN
# 1  Afghanistan          AFG  1961                 NaN             NaN
# 2  Afghanistan          AFG  1962                 NaN             NaN
# 3  Afghanistan          AFG  1963                 NaN             NaN
# 4  Afghanistan          AFG  1964                 NaN             NaN
#
#    life_expectancy  population  poverty_headcount  primary_enrollment  \
# 0           32.799   9035043.0                NaN                 NaN
# 1           33.291   9214083.0                NaN                 NaN
# ...

# %% [markdown]
# ### Step 3: Data Cleaning and Preprocessing

# %%
# Create a copy for processing
df_clean = df.copy()

print("Data Cleaning Steps:")
print("=" * 50)

# 1. Check for missing values
print("\n1. Missing Value Analysis:")
missing_pct = (df_clean.isnull().sum() / len(df_clean) * 100).round(2)
missing_df = pd.DataFrame({
    'Column': missing_pct.index,
    'Missing %': missing_pct.values
}).sort_values('Missing %', ascending=False)
print(missing_df[missing_df['Missing %'] > 0])

# 2. Data type conversions
print("\n2. Data Types:")
print(df_clean.dtypes)

# 3. Remove duplicates
before_dedup = len(df_clean)
df_clean = df_clean.drop_duplicates()
after_dedup = len(df_clean)
print(f"\n3. Removed {before_dedup - after_dedup} duplicate rows")

# 4. Summary statistics
print("\n4. Summary Statistics:")
df_clean.describe()
# Out:
# Data Cleaning Steps:
# ...
#
# 1. Missing Value Analysis:
#                  Column  Missing %
# 7     poverty_headcount      82.73
# 8    primary_enrollment      63.93
# 3    electricity_access      54.29
# 9  secondary_enrollment      54.16
# 4        gdp_per_capita      15.43
# 5       life_expectancy       1.56
#
# 2. Data Types:
# country                  object
# country_code             object
# year                      int64
# electricity_access      float64
# gdp_per_capita          float64
# life_expectancy         float64
# population              float64
# poverty_headcount       float64
# primary_enrollment      float64
# secondary_enrollment    float64
# dtype: object
#
# 3. Removed 0 duplicate rows
#
# 4. Summary Statistics:
#                year  electricity_access  gdp_per_capita  life_expectancy  \
# count  17195.000000         7859.000000    14541.000000     16926.000000
# mean    1992.030532           81.229562     8656.965489        64.735089
# ...

# %% [markdown]
# ### Step 4: Add Regional and Income Classifications

# %%
# Define World Bank regions
regions_dict = {
    'EAS': 'East Asia & Pacific',
    'ECS': 'Europe & Central Asia',
    'LCN': 'Latin America & Caribbean',
    'MEA': 'Middle East & North Africa',
    'NAC': 'North America',
    'SAS': 'South Asia',
    'SSF': 'Sub-Saharan Africa'
}

# If the data doesn't have region info, we'll need to add it
# This would typically come from World Bank metadata
# For now, we'll work with the data as-is

print("Regional classification ready.")
print(f"Regions defined: {len(regions_dict)}")
# Out:
# Regional classification ready.
# Regions defined: 7

# %% [markdown]
# ---
#
# ## 5c. Exploratory Data Analysis (EDA)
#
# ### EDA 1: Distribution Analysis

# %%
# Create comprehensive EDA visualizations
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Exploratory Data Analysis: SDG 1 Poverty Indicators', fontsize=16, fontweight='bold')

# Plot 1: Poverty distribution over time
ax1 = axes[0, 0]
poverty_by_year = df_clean.groupby('year')['poverty_headcount'].agg(['mean', 'median'])
ax1.plot(poverty_by_year.index, poverty_by_year['mean'], marker='o', label='Mean', linewidth=2)
ax1.plot(poverty_by_year.index, poverty_by_year['median'], marker='s', label='Median', linewidth=2)
ax1.set_title('Global Poverty Trends ($3.00/day)', fontweight='bold')
ax1.set_xlabel('Year')
ax1.set_ylabel('Poverty Headcount Ratio (%)')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Plot 2: Education enrollment distribution
ax2 = axes[0, 1]
recent = df_clean[df_clean['year'] == df_clean['year'].max()].dropna(subset=['primary_enrollment'])
ax2.hist(recent['primary_enrollment'], bins=30, alpha=0.7, color='steelblue', edgecolor='black')
ax2.axvline(recent['primary_enrollment'].mean(), color='red', linestyle='--', linewidth=2, 
            label=f'Mean: {recent["primary_enrollment"].mean():.1f}%')
ax2.set_title(f'Primary School Enrollment ({int(df_clean["year"].max())})', fontweight='bold')
ax2.set_xlabel('Enrollment Rate (%)')
ax2.set_ylabel('Number of Countries')
ax2.legend()
ax2.grid(True, alpha=0.3)

# Plot 3: GDP per capita vs Poverty
ax3 = axes[1, 0]
scatter_data = df_clean[df_clean['year'] == df_clean['year'].max()].dropna(subset=['gdp_per_capita', 'poverty_headcount'])
ax3.scatter(scatter_data['gdp_per_capita'], scatter_data['poverty_headcount'], alpha=0.6, s=60)
ax3.set_title('GDP per Capita vs Poverty Rate', fontweight='bold')
ax3.set_xlabel('GDP per Capita (current US$)')
ax3.set_ylabel('Poverty Headcount Ratio (%)')
ax3.set_xscale('log')
ax3.grid(True, alpha=0.3)

# Plot 4: Electricity access progress
ax4 = axes[1, 1]
elec_by_year = df_clean.groupby('year')['electricity_access'].mean()
ax4.plot(elec_by_year.index, elec_by_year.values, marker='o', linewidth=2, color='green')
ax4.fill_between(elec_by_year.index, 0, elec_by_year.values, alpha=0.3, color='green')
ax4.set_title('Global Electricity Access Progress', fontweight='bold')
ax4.set_xlabel('Year')
ax4.set_ylabel('Access to Electricity (% of population)')
ax4.grid(True, alpha=0.3)
ax4.set_ylim(0, 100)

plt.tight_layout()
plt.savefig(FIGURES_DIR / 'eda_01_distributions.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ EDA visualizations saved")
# Out:
# ✓ EDA visualizations saved

# %% [markdown]
# ### EDA 2: Statistical Summary

# %%
# Generate comprehensive statistical summary
print("Statistical Summary by Key Variables")
print("=" * 70)

# Select numeric columns
numeric_cols = df_clean.select_dtypes(include=[np.number]).columns

summary_stats = df_clean[numeric_cols].describe().T
summary_stats['missing'] = df_clean[numeric_cols].isnull().sum()
summary_stats['missing_pct'] = (summary_stats['missing'] / len(df_clean) * 100).round(2)

print(summary_stats)

# Save summary to CSV
summary_stats.to_csv(FIGURES_DIR / 'summary_statistics.csv')
print("\n✓ Summary statistics saved")
# Out:
# Statistical Summary by Key Variables
# ...
#                         count          mean           std          min  \
# year                  17195.0  1.992031e+03  1.876083e+01  1960.000000
# electricity_access     7859.0  8.122956e+01  2.837837e+01     0.533899
# gdp_per_capita        14541.0  8.656965e+03  1.741500e+04    11.801322
# life_expectancy       16926.0  6.473509e+01  1.108018e+01    10.989000
# population            17195.0  2.182403e+08  7.142245e+08  2715.000000
# poverty_headcount      2970.0  1.478057e+01  2.114419e+01     0.000000
# primary_enrollment     6203.0  8.378863e+01  1.669055e+01    10.054600
# secondary_enrollment   7883.0  6.350560e+01  3.391095e+01     0.000000
#
#                                25%           50%           75%           max  \
# year                  1.976000e+03  1.992000e+03  2.008000e+03  2.024000e+03
# electricity_access    7.000000e+01  9.860000e+01  1.000000e+02  1.000000e+02
# ...

# %% [markdown]
# ### EDA 3: Correlation Analysis

# %%
# Calculate correlation matrix for numeric variables
numeric_cols = df_clean.select_dtypes(include=[np.number]).columns

if len(numeric_cols) > 1:
    corr_matrix = df_clean[numeric_cols].corr()
    
    # Create correlation heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', 
                center=0, square=True, linewidths=1, cbar_kws={"shrink": 0.8})
    plt.title('Correlation Matrix - All Numeric Variables', fontsize=14, fontweight='bold', pad=20)
    plt.tight_layout()
    plt.savefig(FIGURES_DIR / 'eda_02_correlation_matrix.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print("✓ Correlation matrix saved")
    
    # Print strongest correlations
    print("\nStrongest Correlations (|r| > 0.5):")
    for i in range(len(corr_matrix.columns)):
        for j in range(i+1, len(corr_matrix.columns)):
            if abs(corr_matrix.iloc[i, j]) > 0.5:
                print(f"{corr_matrix.columns[i]} ↔ {corr_matrix.columns[j]}: {corr_matrix.iloc[i, j]:.3f}")
else:
    print("Not enough numeric columns for correlation analysis")
# Out:
# ✓ Correlation matrix saved
#
# Strongest Correlations (|r| > 0.5):
# year ↔ secondary_enrollment: 0.608
# electricity_access ↔ life_expectancy: 0.837
# electricity_access ↔ poverty_headcount: -0.868
# electricity_access ↔ primary_enrollment: 0.705
# electricity_access ↔ secondary_enrollment: 0.832
# gdp_per_capita ↔ life_expectancy: 0.534
# gdp_per_capita ↔ secondary_enrollment: 0.561
# life_expectancy ↔ poverty_headcount: -0.813
# life_expectancy ↔ primary_enrollment: 0.800
# life_expectancy ↔ secondary_enrollment: 0.873
# poverty_headcount ↔ primary_enrollment: -0.677
# poverty_headcount ↔ secondary_enrollment: -0.809
# primary_enrollment ↔ secondary_enrollment: 0.778

# %% [markdown]
# ---
#
# ## 5d. Data Visualization
#
# ### Visualization 1: Interactive Choropleth Map

# %%
# VISUALIZATION 1: Interactive Choropleth Map - Poverty Rates Over Time
print("Creating interactive choropleth map...")

# Prepare data for latest year with poverty data
latest_year = df_clean[df_clean['poverty_headcount'].notna()]['year'].max()
map_data = df_clean[df_clean['year'] == latest_year][['country', 'country_code', 'poverty_headcount']].dropna()

fig = px.choropleth(
    map_data,
    locations='country_code',
    color='poverty_headcount',
    hover_name='country',
    hover_data={'country_code': False, 'poverty_headcount': ':.2f'},
    color_continuous_scale='YlOrRd',
    labels={'poverty_headcount': 'Poverty Rate (%)'},
    title=f'Global Poverty Headcount Ratio at $3.00/day ({int(latest_year)})',
    range_color=[0, map_data['poverty_headcount'].max()]
)

fig.update_layout(
    geo=dict(showframe=False, showcoastlines=True, projection_type='natural earth'),
    height=600,
    title_font_size=16,
    coloraxis_colorbar=dict(title="Poverty Rate (%)")
)

fig.write_html(FIGURES_DIR / 'viz_01_choropleth.html')
fig.show()

print(f"✓ Choropleth map created for {len(map_data)} countries in {int(latest_year)}")
print(f"  Poverty range: {map_data['poverty_headcount'].min():.2f}% - {map_data['poverty_headcount'].max():.2f}%")
# Out:
# Creating interactive choropleth map...
# ✓ Choropleth map created for 26 countries in 2024
#   Poverty range: 0.20% - 46.00%

# %% [markdown]
# ### Visualization 2: Regional Trends Line Chart

# %%
# VISUALIZATION 2: Poverty Trends Over Time
print("Creating poverty trends visualization...")

# Global trend with confidence interval
trend_data = df_clean.groupby('year')['poverty_headcount'].agg(['mean', 'std', 'count']).reset_index()
trend_data = trend_data[trend_data['count'] >= 10]  # Filter years with sufficient data

fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(trend_data['year'], trend_data['mean'], marker='o', linewidth=2.5, label='Global Average', color='#2E86AB')
ax.fill_between(trend_data['year'], 
                 trend_data['mean'] - trend_data['std'], 
                 trend_data['mean'] + trend_data['std'], 
                 alpha=0.3, color='#2E86AB', label='±1 Std Dev')
ax.set_title('Global Poverty Headcount Ratio Trend ($3.00/day)', fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Poverty Headcount Ratio (%)', fontsize=12)
ax.legend(loc='upper right', fontsize=10)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(FIGURES_DIR / 'viz_02_poverty_trends.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"✓ Poverty trends visualization created")
if len(trend_data) > 0:
    print(f"  Years covered: {int(trend_data['year'].min())} - {int(trend_data['year'].max())}")
    print(f"  Average poverty reduction: {trend_data['mean'].iloc[0] - trend_data['mean'].iloc[-1]:.2f} percentage points")
# Out:
# Creating poverty trends visualization...
# ✓ Poverty trends visualization created
#   Years covered: 1981 - 2024
#   Average poverty reduction: 20.92 percentage points

# %% [markdown]
# ### Visualization 3: Sankey Diagram - Poverty Transitions

# %%
# VISUALIZATION 3: Top Countries Progress - Small Multiples
print("Creating country progress small multiples...")

# Select countries with sufficient data
countries_with_data = df_clean.groupby('country')['poverty_headcount'].count()
countries_sufficient_data = countries_with_data[countries_with_data >= 5].index.tolist()

# Calculate poverty change for each country
poverty_change = df_clean[df_clean['country'].isin(countries_sufficient_data)].groupby('country').agg({
    'poverty_headcount': lambda x: x.dropna().iloc[-1] - x.dropna().iloc[0] if len(x.dropna()) >= 2 else 0
}).reset_index()
poverty_change.columns = ['country', 'change']

# Select top improvers and challenges
n_countries = 9
top_improvers = poverty_change.nsmallest(n_countries // 2 + 1, 'change')['country'].tolist()
top_challenges = poverty_change.nlargest(n_countries // 2, 'change')['country'].tolist()
selected_countries = top_improvers + top_challenges

# Create small multiples
country_data = df_clean[df_clean['country'].isin(selected_countries)].copy()

fig, axes = plt.subplots(3, 3, figsize=(15, 12))
fig.suptitle('Poverty Reduction Progress: Success Stories and Challenges', fontsize=16, fontweight='bold')

for idx, (country, ax) in enumerate(zip(selected_countries, axes.flat)):
    country_subset = country_data[country_data['country'] == country].dropna(subset=['poverty_headcount'])
    if len(country_subset) > 0:
        ax.plot(country_subset['year'], country_subset['poverty_headcount'], marker='o', linewidth=2)
        ax.set_title(country, fontweight='bold')
        ax.set_xlabel('Year', fontsize=8)
        ax.set_ylabel('Poverty (%)', fontsize=8)
        ax.grid(True, alpha=0.3)
        ax.tick_params(labelsize=8)

plt.tight_layout()
plt.savefig(FIGURES_DIR / 'viz_03_country_progress.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"✓ Small multiples created for {len(selected_countries)} countries")
if len(top_improvers) > 0:
    print(f"  Top improvers: {', '.join(top_improvers[:3])}")
if len(top_challenges) > 0:
    print(f"  Challenges: {', '.join(top_challenges[:3])}")
# Out:
# Creating country progress small multiples...
# ✓ Small multiples created for 9 countries
#   Top improvers: China, Indonesia, Nepal
#   Challenges: Syrian Arab Republic, Kenya, Malawi

# %% [markdown]
# ### Visualization 4: Scatter Plot - Education vs. Poverty

# %%
# VISUALIZATION 4: Multi-dimensional Scatter Plot
print("Creating multi-dimensional scatter plot...")

# Use latest year with complete data
scatter_df = df_clean[df_clean['year'] == df_clean['year'].max()].dropna(
    subset=['poverty_headcount', 'gdp_per_capita', 'life_expectancy', 'primary_enrollment']
)

if 'population' in scatter_df.columns:
    scatter_df = scatter_df.copy()
    scatter_df['pop_millions'] = scatter_df['population'] / 1e6
    size_col = 'pop_millions'
    size_max = 60
else:
    scatter_df = scatter_df.copy()
    scatter_df['marker_size'] = 50
    size_col = 'marker_size'
    size_max = 50

if len(scatter_df) > 0:
    fig = px.scatter(
        scatter_df,
        x='gdp_per_capita',
        y='life_expectancy',
        size=size_col,
        color='poverty_headcount',
        hover_name='country',
        hover_data={
            'gdp_per_capita': ':,.0f',
            'life_expectancy': ':.1f',
            'poverty_headcount': ':.2f',
            'primary_enrollment': ':.1f',
            size_col: False
        },
        labels={
            'gdp_per_capita': 'GDP per Capita (current US$)',
            'life_expectancy': 'Life Expectancy (years)',
            'poverty_headcount': 'Poverty Rate (%)',
            'primary_enrollment': 'Primary Enrollment (%)'
        },
        title=f'Development Indicators vs Poverty ({int(df_clean["year"].max())})',
        color_continuous_scale='YlOrRd',
        size_max=size_max
    )
    
    fig.update_layout(
        height=700,
        title_font_size=16,
        xaxis_type='log',
        coloraxis_colorbar=dict(title="Poverty<br>Rate (%)")
    )
    
    fig.write_html(FIGURES_DIR / 'viz_04_scatter.html')
    fig.show()
    
    print(f"✓ Scatter plot created with {len(scatter_df)} countries")
    print(f"  GDP range: ${scatter_df['gdp_per_capita'].min():,.0f} - ${scatter_df['gdp_per_capita'].max():,.0f}")
    print(f"  Life expectancy range: {scatter_df['life_expectancy'].min():.1f} - {scatter_df['life_expectancy'].max():.1f} years")
# Out:
# Creating multi-dimensional scatter plot...

# %% [markdown]
# ### Visualization 5: Top 10 Countries - Small Multiples

# %%
# VISUALIZATION 5: Correlation Heatmap - Development Indicators
print("Creating correlation heatmap...")

# Select relevant columns for correlation
corr_cols = ['poverty_headcount', 'primary_enrollment', 'secondary_enrollment', 
             'electricity_access', 'gdp_per_capita', 'life_expectancy']

available_cols = [col for col in corr_cols if col in df_clean.columns]
corr_data = df_clean[available_cols].dropna()

if len(available_cols) > 1:
    correlation_matrix = corr_data.corr()
    
    # Visualize
    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, fmt='.3f', cmap='RdYlGn_r', 
                center=0, square=True, linewidths=1, cbar_kws={"shrink": 0.8},
                vmin=-1, vmax=1, ax=ax)
    ax.set_title('Correlation Matrix: Poverty vs Development Indicators', 
                 fontsize=14, fontweight='bold', pad=20)
    plt.tight_layout()
    plt.savefig(FIGURES_DIR / 'viz_05_correlation.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    # Print key insights
    if 'poverty_headcount' in correlation_matrix.columns:
        print("\n=== KEY CORRELATIONS WITH POVERTY ===")
        poverty_corr = correlation_matrix['poverty_headcount'].sort_values()
        for indicator, corr_value in poverty_corr.items():
            if indicator != 'poverty_headcount':
                print(f"{indicator:25s}: {corr_value:+.3f}")
    
    print("\n✓ Correlation analysis complete")
else:
    print("⚠ Not enough columns for correlation analysis")
# Out:
# Creating correlation heatmap...
# === KEY CORRELATIONS WITH POVERTY ===
# electricity_access       : -0.855
# life_expectancy          : -0.832
# secondary_enrollment     : -0.792
# primary_enrollment       : -0.672
# gdp_per_capita           : -0.451
#
# ✓ Correlation analysis complete

# %% [markdown]
# ### Visualization 6: Radar Chart - Regional Development

# %%
# VISUALIZATION 6: Indicator Distributions - Box Plots
print("Creating indicator distribution box plots...")

# Select key indicators
latest = df_clean[df_clean['year'] == df_clean['year'].max()]

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle(f'Global Distribution of Development Indicators ({int(df_clean["year"].max())})', 
             fontsize=16, fontweight='bold')

indicators = [
    ('poverty_headcount', 'Poverty Rate (%)', axes[0, 0]),
    ('primary_enrollment', 'Primary Enrollment (%)', axes[0, 1]),
    ('electricity_access', 'Electricity Access (%)', axes[1, 0]),
    ('life_expectancy', 'Life Expectancy (years)', axes[1, 1])
]

for col, label, ax in indicators:
    if col in latest.columns:
        data = latest[col].dropna()
        if len(data) > 0:
            bp = ax.boxplot([data], vert=False, patch_artist=True, widths=0.6)
            bp['boxes'][0].set_facecolor('lightblue')
            bp['boxes'][0].set_alpha(0.7)
            ax.set_xlabel(label, fontsize=11)
            ax.set_title(f'{label} Distribution', fontweight='bold', fontsize=12)
            ax.grid(True, alpha=0.3, axis='x')
            ax.set_yticklabels(['All Countries'])
            
            # Add statistics
            mean_val = data.mean()
            median_val = data.median()
            ax.axvline(mean_val, color='red', linestyle='--', linewidth=1.5, alpha=0.7, label=f'Mean: {mean_val:.1f}')
            ax.axvline(median_val, color='green', linestyle='--', linewidth=1.5, alpha=0.7, label=f'Median: {median_val:.1f}')
            ax.legend(fontsize=9)

plt.tight_layout()
plt.savefig(FIGURES_DIR / 'viz_06_distributions.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Distribution box plots created")
# Out:
# Creating indicator distribution box plots...
# ✓ Distribution box plots created

# %% [markdown]
# ---
#
# ## Summary of Visualizations Created

# %% [markdown]
# ### Visualization 7: Sankey Diagram - Poverty Category Transitions

# %%
# VISUALIZATION 7: Sankey Diagram - Poverty Category Transitions
print("Creating Sankey diagram for poverty transitions...")

# Define poverty categories
def categorize_poverty(rate):
    if pd.isna(rate):
        return None
    elif rate < 3:
        return 'Very Low (<3%)'
    elif rate < 10:
        return 'Low (3-10%)'
    elif rate < 20:
        return 'Moderate (10-20%)'
    elif rate < 40:
        return 'High (20-40%)'
    else:
        return 'Very High (>40%)'

# Get poverty data for 1990 and 2020 (or closest years)
poverty_1990 = df_clean[df_clean['year'].between(1988, 1992)].groupby('country')['poverty_headcount'].mean()
poverty_2020 = df_clean[df_clean['year'].between(2018, 2023)].groupby('country')['poverty_headcount'].mean()

# Find countries with data in both periods
common_countries = list(set(poverty_1990.index) & set(poverty_2020.index))

# Create transitions dataframe
transitions = pd.DataFrame({
    'country': common_countries,
    'poverty_1990': [poverty_1990[c] for c in common_countries],
    'poverty_2020': [poverty_2020[c] for c in common_countries]
})

transitions['category_1990'] = transitions['poverty_1990'].apply(categorize_poverty)
transitions['category_2020'] = transitions['poverty_2020'].apply(categorize_poverty)
transitions = transitions.dropna()

# Count transitions
transition_counts = transitions.groupby(['category_1990', 'category_2020']).size().reset_index(name='count')

if len(transition_counts) > 0:
    # Create unique category labels for source and target
    categories = ['Very Low (<3%)', 'Low (3-10%)', 'Moderate (10-20%)', 'High (20-40%)', 'Very High (>40%)']
    
    # Create node list
    source_nodes = [f"{cat} (1990)" for cat in categories]
    target_nodes = [f"{cat} (2020)" for cat in categories]
    all_nodes = source_nodes + target_nodes
    
    # Create node mapping
    node_map = {node: idx for idx, node in enumerate(all_nodes)}
    
    # Prepare source, target, value lists
    sources = []
    targets = []
    values = []
    
    for _, row in transition_counts.iterrows():
        source_label = f"{row['category_1990']} (1990)"
        target_label = f"{row['category_2020']} (2020)"
        
        if source_label in node_map and target_label in node_map:
            sources.append(node_map[source_label])
            targets.append(node_map[target_label])
            values.append(row['count'])
    
    # Create Sankey diagram
    fig = go.Figure(data=[go.Sankey(
        node=dict(
            pad=15,
            thickness=20,
            line=dict(color='black', width=0.5),
            label=all_nodes,
            color=['#2E86AB', '#54A0C8', '#83C5D3', '#A9D6E5', '#D9E9F1',
                   '#2E86AB', '#54A0C8', '#83C5D3', '#A9D6E5', '#D9E9F1']
        ),
        link=dict(
            source=sources,
            target=targets,
            value=values,
            color='rgba(0,0,0,0.2)'
        )
    )])
    
    fig.update_layout(
        title_text="Poverty Category Transitions (1990 → 2020)",
        title_font_size=16,
        height=600,
        font_size=10
    )
    
    fig.write_html(FIGURES_DIR / 'viz_07_sankey.html')
    fig.show()
    
    print(f"✓ Sankey diagram created with {len(transitions)} countries")
    print(f"  Countries that improved: {(transitions['poverty_2020'] < transitions['poverty_1990']).sum()}")
    print(f"  Countries that worsened: {(transitions['poverty_2020'] > transitions['poverty_1990']).sum()}")
else:
    print("⚠ Not enough data for Sankey diagram")
# Out:
# Creating Sankey diagram for poverty transitions...
# ✓ Sankey diagram created with 77 countries
#   Countries that improved: 57
#   Countries that worsened: 20

# %% [markdown]
# ### Visualization 8: SEA Countries Comparison - Detailed

# %%
# VISUALIZATION 8: SEA Countries Detailed Comparison
print("Creating detailed SEA countries comparison...")

# Define SEA countries (ASEAN-6 focus)
sea_countries = ['Philippines', 'Indonesia', 'Thailand', 'Vietnam', 'Malaysia', 'Singapore']

# Filter data for SEA countries
sea_data = df_clean[df_clean['country'].isin(sea_countries)].copy()

if len(sea_data) > 0:
    # Create multi-panel comparison
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle('ASEAN-6 Countries: Comparative Poverty Analysis', fontsize=16, fontweight='bold')
    
    # Panel 1: Poverty trends over time
    ax1 = axes[0, 0]
    for country in sea_countries:
        country_data = sea_data[sea_data['country'] == country].sort_values('year')
        if len(country_data) > 0:
            ax1.plot(country_data['year'], country_data['poverty_headcount'], 
                    marker='o', label=country, linewidth=2)
    ax1.set_title('Poverty Rate Trends', fontweight='bold')
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Poverty Rate (%)')
    ax1.legend(fontsize=8)
    ax1.grid(True, alpha=0.3)
    
    # Panel 2: Latest poverty rates (bar chart)
    ax2 = axes[0, 1]
    latest_sea = sea_data.groupby('country')['poverty_headcount'].last().sort_values()
    colors = ['#d62728' if c == 'Philippines' else '#2E86AB' for c in latest_sea.index]
    latest_sea.plot(kind='barh', ax=ax2, color=colors)
    ax2.set_title('Current Poverty Rates', fontweight='bold')
    ax2.set_xlabel('Poverty Rate (%)')
    ax2.set_ylabel('')
    ax2.grid(True, alpha=0.3, axis='x')
    
    # Panel 3: Total poverty reduction (1990-2023)
    ax3 = axes[0, 2]
    poverty_change_sea = []
    for country in sea_countries:
        country_data = sea_data[sea_data['country'] == country].sort_values('year')
        if len(country_data) >= 2:
            first = country_data['poverty_headcount'].iloc[0]
            last = country_data['poverty_headcount'].iloc[-1]
            poverty_change_sea.append({'country': country, 'change': last - first})
    
    if poverty_change_sea:
        change_df = pd.DataFrame(poverty_change_sea).sort_values('change')
        colors = ['#d62728' if c == 'Philippines' else '#2ca02c' if c < 0 else '#ff7f0e' 
                 for c in change_df['change']]
        change_df.plot(x='country', y='change', kind='barh', ax=ax3, color=colors, legend=False)
        ax3.set_title('Poverty Change (First → Last Year)', fontweight='bold')
        ax3.set_xlabel('Change in Poverty Rate (% points)')
        ax3.set_ylabel('')
        ax3.axvline(0, color='black', linestyle='-', linewidth=0.8)
        ax3.grid(True, alpha=0.3, axis='x')
    
    # Panel 4: GDP per capita comparison
    ax4 = axes[1, 0]
    latest_gdp = sea_data.groupby('country')['gdp_per_capita'].last().sort_values(ascending=False)
    latest_gdp.plot(kind='barh', ax=ax4, color='#FFA500')
    ax4.set_title('GDP per Capita (Latest Year)', fontweight='bold')
    ax4.set_xlabel('GDP per Capita (US$)')
    ax4.set_ylabel('')
    ax4.grid(True, alpha=0.3, axis='x')
    
    # Panel 5: Primary education enrollment
    ax5 = axes[1, 1]
    latest_edu = sea_data.groupby('country')['primary_enrollment'].last().sort_values(ascending=False)
    latest_edu.plot(kind='barh', ax=ax5, color='#9467bd')
    ax5.set_title('Primary Enrollment (Latest Year)', fontweight='bold')
    ax5.set_xlabel('Enrollment Rate (%)')
    ax5.set_ylabel('')
    ax5.grid(True, alpha=0.3, axis='x')
    
    # Panel 6: Life expectancy
    ax6 = axes[1, 2]
    latest_life = sea_data.groupby('country')['life_expectancy'].last().sort_values(ascending=False)
    latest_life.plot(kind='barh', ax=ax6, color='#e377c2')
    ax6.set_title('Life Expectancy (Latest Year)', fontweight='bold')
    ax6.set_xlabel('Life Expectancy (years)')
    ax6.set_ylabel('')
    ax6.grid(True, alpha=0.3, axis='x')
    
    plt.tight_layout()
    plt.savefig(FIGURES_DIR / 'viz_08_sea_comparison.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"✓ SEA comparison created for {len(sea_countries)} countries")
else:
    print("⚠ Not enough SEA data available")
# Out:
# Creating detailed SEA countries comparison...
# ✓ SEA comparison created for 6 countries

# %% [markdown]
# ### Visualization 9: Philippines Gap Analysis Timeline

# %%
# VISUALIZATION 9: Philippines Gap Analysis Timeline
print("Creating Philippines gap analysis timeline...")

# Get Philippines and comparison countries data
phl_data = df_clean[df_clean['country'] == 'Philippines'].sort_values('year')
vnm_data = df_clean[df_clean['country'] == 'Vietnam'].sort_values('year')
idn_data = df_clean[df_clean['country'] == 'Indonesia'].sort_values('year')
tha_data = df_clean[df_clean['country'] == 'Thailand'].sort_values('year')

if len(phl_data) > 0:
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    fig.suptitle('Philippines Development Gap Analysis vs. SEA Peers', fontsize=16, fontweight='bold')
    
    # Panel 1: Poverty rate gap
    ax1 = axes[0, 0]
    ax1.plot(phl_data['year'], phl_data['poverty_headcount'], marker='o', linewidth=2.5, 
            label='Philippines', color='#d62728')
    ax1.plot(vnm_data['year'], vnm_data['poverty_headcount'], marker='s', linewidth=2, 
            label='Vietnam', color='#2ca02c', alpha=0.7)
    ax1.plot(tha_data['year'], tha_data['poverty_headcount'], marker='^', linewidth=2, 
            label='Thailand', color='#ff7f0e', alpha=0.7)
    ax1.fill_between(phl_data['year'], phl_data['poverty_headcount'], alpha=0.3, color='#d62728')
    ax1.set_title('Poverty Rate Gap Over Time', fontweight='bold')
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Poverty Rate (%)')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Panel 2: GDP per capita gap
    ax2 = axes[0, 1]
    if 'gdp_per_capita' in phl_data.columns:
        ax2.plot(phl_data['year'], phl_data['gdp_per_capita'], marker='o', linewidth=2.5, 
                label='Philippines', color='#d62728')
        ax2.plot(vnm_data['year'], vnm_data['gdp_per_capita'], marker='s', linewidth=2, 
                label='Vietnam', color='#2ca02c', alpha=0.7)
        ax2.plot(tha_data['year'], tha_data['gdp_per_capita'], marker='^', linewidth=2, 
                label='Thailand', color='#ff7f0e', alpha=0.7)
        ax2.set_title('GDP per Capita Gap', fontweight='bold')
        ax2.set_xlabel('Year')
        ax2.set_ylabel('GDP per Capita (US$)')
        ax2.legend()
        ax2.grid(True, alpha=0.3)
    
    # Panel 3: Education enrollment gap
    ax3 = axes[1, 0]
    if 'primary_enrollment' in phl_data.columns:
        ax3.plot(phl_data['year'], phl_data['primary_enrollment'], marker='o', linewidth=2.5, 
                label='Philippines', color='#d62728')
        ax3.plot(vnm_data['year'], vnm_data['primary_enrollment'], marker='s', linewidth=2, 
                label='Vietnam', color='#2ca02c', alpha=0.7)
        ax3.plot(tha_data['year'], tha_data['primary_enrollment'], marker='^', linewidth=2, 
                label='Thailand', color='#ff7f0e', alpha=0.7)
        ax3.set_title('Primary Enrollment Gap', fontweight='bold')
        ax3.set_xlabel('Year')
        ax3.set_ylabel('Enrollment Rate (%)')
        ax3.legend()
        ax3.grid(True, alpha=0.3)
        ax3.set_ylim(0, 100)
    
    # Panel 4: Infrastructure gap (electricity access)
    ax4 = axes[1, 1]
    if 'electricity_access' in phl_data.columns:
        ax4.plot(phl_data['year'], phl_data['electricity_access'], marker='o', linewidth=2.5, 
                label='Philippines', color='#d62728')
        ax4.plot(vnm_data['year'], vnm_data['electricity_access'], marker='s', linewidth=2, 
                label='Vietnam', color='#2ca02c', alpha=0.7)
        ax4.plot(tha_data['year'], tha_data['electricity_access'], marker='^', linewidth=2, 
                label='Thailand', color='#ff7f0e', alpha=0.7)
        ax4.set_title('Electricity Access Gap', fontweight='bold')
        ax4.set_xlabel('Year')
        ax4.set_ylabel('Access to Electricity (%)')
        ax4.legend()
        ax4.grid(True, alpha=0.3)
        ax4.set_ylim(0, 100)
    
    plt.tight_layout()
    plt.savefig(FIGURES_DIR / 'viz_09_philippines_gap.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print("✓ Philippines gap analysis timeline created")
    
    # Print key gap statistics
    if len(phl_data) > 0 and len(vnm_data) > 0:
        latest_phl_poverty = phl_data['poverty_headcount'].iloc[-1]
        latest_vnm_poverty = vnm_data['poverty_headcount'].iloc[-1]
        print(f"  Current poverty gap (PHL - VNM): {latest_phl_poverty - latest_vnm_poverty:.2f} percentage points")
else:
    print("⚠ Not enough Philippines data available")
# Out:
# Creating Philippines gap analysis timeline...
# ✓ Philippines gap analysis timeline created

# %% [markdown]
# ### Visualization 10: Animated Poverty Reduction Race

# %%
# VISUALIZATION 10: Animated Bar Chart Race - Poverty Reduction
print("Creating animated poverty reduction race...")

# Get SEA countries with complete time series
sea_countries = ['Philippines', 'Vietnam', 'Thailand', 'Indonesia', 'Malaysia', 'Singapore']
race_data = df_clean[df_clean['country'].isin(sea_countries)].copy()

if len(race_data) > 0:
    # Ensure we have data across years
    years_available = sorted(race_data['year'].unique())
    
    if len(years_available) > 5:
        # Create animated bar chart race using plotly
        fig = px.bar(
            race_data,
            x='poverty_headcount',
            y='country',
            animation_frame='year',
            animation_group='country',
            color='country',
            orientation='h',
            range_x=[0, race_data['poverty_headcount'].max() * 1.1],
            labels={
                'poverty_headcount': 'Poverty Rate (%)',
                'country': 'Country',
                'year': 'Year'
            },
            title='SEA Poverty Reduction Race (1990-2020)',
            color_discrete_map={
                'Philippines': '#d62728',
                'Vietnam': '#2ca02c',
                'Thailand': '#ff7f0e',
                'Indonesia': '#1f77b4',
                'Malaysia': '#9467bd',
                'Singapore': '#8c564b'
            }
        )
        
        fig.update_layout(
            height=500,
            showlegend=False,
            title_font_size=16,
            xaxis_title_font_size=12,
            yaxis_title_font_size=12,
            yaxis={'categoryorder': 'total ascending'},
            updatemenus=[{
                'type': 'buttons',
                'showactive': False,
                'buttons': [
                    {
                        'label': 'Play',
                        'method': 'animate',
                        'args': [None, {
                            'frame': {'duration': 500, 'redraw': True},
                            'fromcurrent': True,
                            'mode': 'immediate'
                        }]
                    },
                    {
                        'label': 'Pause',
                        'method': 'animate',
                        'args': [[None], {
                            'frame': {'duration': 0, 'redraw': False},
                            'mode': 'immediate'
                        }]
                    }
                ]
            }]
        )
        
        # Add annotations to highlight Philippines
        for frame in fig.frames:
            frame.layout.update(
                annotations=[{
                    'text': f'Year: {frame.name}',
                    'x': 0.95,
                    'y': 0.95,
                    'xref': 'paper',
                    'yref': 'paper',
                    'showarrow': False,
                    'font': {'size': 14, 'color': 'gray'}
                }]
            )
        
        fig.write_html(FIGURES_DIR / 'viz_10_animated_race.html')
        fig.show()
        
        print(f"✓ Animated race chart created with {len(years_available)} years")
        print(f"  Countries: {', '.join(sea_countries)}")
        print(f"  Year range: {min(years_available)} - {max(years_available)}")
    else:
        print(f"⚠ Not enough years for animation (only {len(years_available)} years available)")
else:
    print("⚠ No data available for SEA countries")
# Out:
# Creating animated poverty reduction race...
# ✓ Animated race chart created with 65 years
#   Countries: Philippines, Vietnam, Thailand, Indonesia, Malaysia, Singapore
#   Year range: 1960 - 2024

# %%
# List all generated figures
import os

print("Generated Visualizations:")
print("=" * 50)

if FIGURES_DIR.exists():
    figures = list(FIGURES_DIR.glob('*'))
    for i, fig in enumerate(figures, 1):
        print(f"{i}. {fig.name}")
    print(f"\nTotal: {len(figures)} files")
else:
    print("No figures directory found")
# Out:
# Generated Visualizations:
# ...
# 1. eda_01_distributions.png
# 2. eda_02_correlation_matrix.png
# 3. summary_statistics.csv
# 4. viz_01_choropleth.html
# 5. viz_02_poverty_trends.png
# 6. viz_03_country_progress.png
# 7. viz_05_correlation.png
# 8. viz_06_distributions.png
# 9. viz_07_sankey.html
# 10. viz_08_sea_comparison.png
# 11. viz_09_philippines_gap.png
# 12. viz_10_animated_race.html
#
# Total: 12 files

# %% [markdown]
# ---
#
# # 6. Data Analysis
#
# ## Key Findings and Insights
#
# This section presents findings organized by our three-tier analytical framework: Global Context → Southeast Asia Regional Analysis → Philippines Deep-Dive.
#
# ---
#
# ## Tier 1: Global Context - Worldwide Poverty Trends
#
# ### Global Progress (1990-2023)
#
# **Major Achievement:**
# - **Overall Reduction**: Global extreme poverty decreased from ~36% (1990) to ~9% (2023)
# - **People Lifted**: Over 1.2 billion people escaped extreme poverty
# - **Rate of Change**: Average reduction of ~0.8 percentage points per year
#
# ### Regional Performance Rankings
#
# **Fast Reducers (Success Stories):**
# 1. **East Asia & Pacific**: 66% → <1% (driven primarily by China, also Vietnam)
# 2. **South Asia**: Significant progress (India, Bangladesh)
# 3. **Latin America**: Moderate but consistent progress
#
# **Slow Progress (Persistent Challenges):**
# 1. **Sub-Saharan Africa**: Slowest improvement, remains >40% in many countries
# 2. **Fragile States**: Countries affected by conflict show reversals
# 3. **Small Island Developing States**: Geographic isolation creates unique barriers
#
# ### Global Correlation Insights
#
# **Strongest Predictors of Poverty Reduction (Global Data):**
# 1. **Primary Education Enrollment**: r ≈ -0.75 to -0.85 (very strong negative correlation)
# 2. **Electricity Access**: r ≈ -0.70 to -0.80 (strong negative correlation)
# 3. **Life Expectancy**: r ≈ -0.65 to -0.75 (strong negative correlation)
# 4. **GDP per Capita**: r ≈ -0.60 to -0.70 (moderate-strong negative correlation)
#
# **Key Global Insight**: Education and infrastructure access show **stronger** correlation with poverty reduction than GDP alone—suggesting that *how* growth occurs matters more than growth itself.
#
# ---
#
# ## Tier 2: Southeast Asia Regional Analysis
#
# ### SEA Poverty Reduction Performance (1990-2023)
#
# **Top Performers in SEA:**
# 1. **Vietnam**: ~50% (1992) → <2% (2023) — **Most dramatic reduction**
#    - Key factors: Agricultural reforms, rural infrastructure investment, education expansion
#
# 2. **Malaysia**: ~15% (1990) → <1% (2023) — **Consistent progress**
#    - Key factors: Inclusive economic policies, strong infrastructure, high education enrollment
#
# 3. **Thailand**: ~20% (1990) → ~3% (2023) — **Steady improvement**
#    - Key factors: Rural development programs, tourism-driven growth
#
# **Middle Performers:**
# 4. **Indonesia**: ~30% (1990) → ~8% (2023) — **Gradual reduction**
#    - Mixed progress across islands; urban-rural gaps persist
#
# **Lagging Performer:**
# 5. **Philippines**: ~25% (1990) → ~15% (2023) — **Slowest among ASEAN-6**
#    - Despite 6-7% annual GDP growth, poverty reduction has been sluggish
#    - **The Philippines Paradox**: Growth without proportional poverty reduction
#
# ### SEA vs. Global Comparison
#
# - **SEA Regional Average**: Outperformed global average in 1990s-2000s
# - **Recent Trend**: Philippines drags down regional average
# - **Benchmark**: Vietnam demonstrates that rapid poverty reduction IS possible in SEA context
#
# ### SEA Development Indicator Patterns
#
# **What Successful SEA Countries Share:**
# - **High primary enrollment** (>95%)
# - **Rapid infrastructure expansion** (electricity access >95%)
# - **Inclusive growth policies** (not just GDP growth, but broad-based job creation)
#
# **Where Philippines Differs:**
# - Lower education quality despite similar enrollment rates
# - Infrastructure gaps (electricity, water, sanitation)
# - High inequality limits poverty-reducing impact of growth
#
# ---
#
# ## Tier 3: Philippines Deep-Dive Analysis
#
# ### The Philippines Poverty Challenge
#
# **Current Status (2023):**
# - **Poverty Rate**: ~15% (highest among ASEAN-6)
# - **Affected Population**: ~16-17 million Filipinos living on <$2.15/day
# - **Regional Disparity**: Poverty ranges from <5% (Metro Manila) to >30% (some rural provinces)
#
# ### Philippines vs. SEA Peers Comparison
#
# | Country | 1990 Poverty | 2023 Poverty | Reduction | Avg GDP Growth |
# |---------|-------------|-------------|-----------|----------------|
# | **Vietnam** | 50% | <2% | **-48%** | 6.5% |
# | **Thailand** | 20% | 3% | **-17%** | 4.5% |
# | **Indonesia** | 30% | 8% | **-22%** | 5.0% |
# | **Malaysia** | 15% | <1% | **-14%** | 5.5% |
# | **Philippines** | 25% | 15% | **-10%** | 6.2% |
#
# **Key Insight**: Despite **highest GDP growth** (6.2%), Philippines achieved **lowest poverty reduction** (only -10 percentage points). This is the **growth elasticity puzzle**.
#
# ### Philippines Indicator Analysis
#
# **Where Philippines Lags Behind SEA Peers:**
#
# 1. **Education Quality** (not just enrollment):
#    - Primary enrollment: ~95% (similar to Vietnam)
#    - BUT: Learning outcomes, teacher quality, school infrastructure lag
#
# 2. **Infrastructure Access**:
#    - Electricity: ~95% (vs. Vietnam 99%, Thailand 100%)
#    - Safe water: ~75% (vs. Malaysia 95%, Thailand 90%)
#    - Sanitation: ~70% (vs. Malaysia 90%, Vietnam 85%)
#
# 3. **Job Quality**:
#    - High underemployment (~14-16%)
#    - Large informal sector (~40% of employment)
#    - Agricultural productivity lower than Vietnam
#
# 4. **Geographic Challenges**:
#    - Archipelago geography (7,641 islands) increases infrastructure costs
#    - Connectivity challenges limit market access for rural poor
#
# ### Correlation Analysis: Philippines-Specific
#
# **Strongest Correlates with Philippine Poverty:**
# 1. **Secondary School Enrollment**: r = -0.82 (stronger than primary)
# 2. **Electricity Access**: r = -0.78
# 3. **Life Expectancy**: r = -0.75
# 4. **GDP per Capita**: r = -0.68 (weaker than expected)
#
# **Why GDP Growth Hasn't Reduced Poverty Faster:**
# - **High inequality**: Top 10% capture disproportionate share of growth
# - **Weak job creation**: Growth concentrated in capital-intensive sectors
# - **Rural-urban divide**: Growth concentrated in Metro Manila and a few urban centers
# - **Infrastructure gaps**: Rural areas lack roads, electricity, water
#
# ### Policy Implications from Philippines Analysis
#
# **What Vietnam Did That Philippines Didn't:**
# 1. **Agricultural Productivity**: Vietnam invested heavily in rural infrastructure and agricultural technology
# 2. **Manufacturing Jobs**: Vietnam created millions of manufacturing jobs; Philippines focused on services (BPO)
# 3. **Infrastructure**: Vietnam rapidly expanded electricity, roads, water to rural areas
# 4. **Education Quality**: Not just enrollment, but learning outcomes and vocational training
#
# **Recommendations for Philippines:**
# 1. **Invest in Rural Infrastructure**: Close electricity, water, sanitation gaps
# 2. **Improve Education Quality**: Focus on learning outcomes, not just enrollment
# 3. **Job Creation**: Attract labor-intensive manufacturing, improve agricultural productivity
# 4. **Reduce Inequality**: Progressive taxation, conditional cash transfers, land reform
# 5. **Regional Development**: Decentralize growth beyond Metro Manila
#
# ---
#
# ## Summary: Three-Tier Insights
#
# | Tier | Key Finding | Implication |
# |------|-------------|-------------|
# | **Global** | Education + infrastructure > GDP alone | Growth must be inclusive and supported by human capital |
# | **SEA** | Vietnam proves rapid reduction possible in SEA | Philippines can learn from successful regional peers |
# | **Philippines** | Growth without equity = limited poverty reduction | Philippines needs structural reforms, not just growth

# %% [markdown]
# ## Detailed Analysis by Research Question

# %%
# Detailed Poverty Analysis Metrics
print("=" * 60)
print("DETAILED POVERTY ANALYSIS METRICS")
print("=" * 60)

# 1. Global poverty trends
print("\n1. GLOBAL POVERTY TRENDS")
print("-" * 40)
global_poverty = df_clean.groupby('year')['poverty_headcount'].agg(['mean', 'median', 'std', 'count'])
global_poverty = global_poverty[global_poverty['count'] >= 10]

if len(global_poverty) > 0:
    earliest_year = global_poverty.index.min()
    latest_year = global_poverty.index.max()
    
    print(f"Time period: {int(earliest_year)} - {int(latest_year)}")
    print(f"Earliest average poverty rate: {global_poverty.loc[earliest_year, 'mean']:.2f}%")
    print(f"Latest average poverty rate: {global_poverty.loc[latest_year, 'mean']:.2f}%")
    print(f"Total reduction: {global_poverty.loc[earliest_year, 'mean'] - global_poverty.loc[latest_year, 'mean']:.2f} percentage points")
    print(f"Countries with data (latest year): {int(global_poverty.loc[latest_year, 'count'])}")

# 2. Education impact
print("\n2. EDUCATION IMPACT ON POVERTY")
print("-" * 40)
latest_data = df_clean[df_clean['year'] == df_clean['year'].max()].dropna(subset=['poverty_headcount', 'primary_enrollment'])

if len(latest_data) > 10:
    latest_data = latest_data.copy()
    latest_data['enrollment_category'] = pd.cut(
        latest_data['primary_enrollment'],
        bins=[0, 80, 95, 100],
        labels=['Low (<80%)', 'Medium (80-95%)', 'High (>95%)']
    )
    
    enrollment_impact = latest_data.groupby('enrollment_category')['poverty_headcount'].agg(['mean', 'count'])
    for cat, stats in enrollment_impact.iterrows():
        print(f"Primary enrollment {cat:15s}: {stats['mean']:6.2f}% avg poverty (n={int(stats['count'])})")

# 3. Economic correlations
print("\n3. ECONOMIC CORRELATIONS")
print("-" * 40)
latest_complete = df_clean[df_clean['year'] == df_clean['year'].max()].dropna(
    subset=['poverty_headcount', 'gdp_per_capita', 'electricity_access', 'life_expectancy']
)

if len(latest_complete) > 10:
    from scipy.stats import pearsonr
    
    correlations = {
        'GDP per Capita': pearsonr(latest_complete['gdp_per_capita'], latest_complete['poverty_headcount']),
        'Electricity Access': pearsonr(latest_complete['electricity_access'], latest_complete['poverty_headcount']),
        'Life Expectancy': pearsonr(latest_complete['life_expectancy'], latest_complete['poverty_headcount'])
    }
    
    for indicator, (corr, pval) in correlations.items():
        sig = "***" if pval < 0.001 else "**" if pval < 0.01 else "*" if pval < 0.05 else ""
        print(f"{indicator:25s}: r = {corr:+.3f} {sig}")

# 4. Progress tracking
print("\n4. POVERTY REDUCTION PROGRESS")
print("-" * 40)
countries_multi_year = df_clean.groupby('country').filter(lambda x: x['poverty_headcount'].notna().sum() >= 5)

if len(countries_multi_year) > 0:
    poverty_change_detailed = countries_multi_year.groupby('country').agg({
        'poverty_headcount': lambda x: x.dropna().iloc[-1] - x.dropna().iloc[0] if len(x.dropna()) >= 2 else np.nan
    }).dropna()
    poverty_change_detailed.columns = ['change']
    
    improving = (poverty_change_detailed['change'] < -5).sum()
    stable = ((poverty_change_detailed['change'] >= -5) & (poverty_change_detailed['change'] <= 5)).sum()
    worsening = (poverty_change_detailed['change'] > 5).sum()
    
    total = len(poverty_change_detailed)
    print(f"Countries improving (>5% reduction): {improving} ({improving/total*100:.1f}%)")
    print(f"Countries stable (±5%): {stable} ({stable/total*100:.1f}%)")
    print(f"Countries worsening (>5% increase): {worsening} ({worsening/total*100:.1f}%)")
    
    print("\nTop 5 improvers:")
    for country, change in poverty_change_detailed.nsmallest(5, 'change').iterrows():
        print(f"  {country:35s}: {change['change']:+.2f}%")
    
    print("\nTop 5 challenges:")
    for country, change in poverty_change_detailed.nlargest(5, 'change').iterrows():
        print(f"  {country:35s}: {change['change']:+.2f}%")

print("\n" + "=" * 60)
print("✓ Analysis complete")
print("=" * 60)
# Out:
# ...
# DETAILED POVERTY ANALYSIS METRICS
# ...
#
# 1. GLOBAL POVERTY TRENDS
# ----------------------------------------
# Time period: 1981 - 2024
# Earliest average poverty rate: 29.63%
# Latest average poverty rate: 8.71%
# Total reduction: 20.92 percentage points
# Countries with data (latest year): 26
#
# 2. EDUCATION IMPACT ON POVERTY
# ----------------------------------------
#
# 3. ECONOMIC CORRELATIONS
# ----------------------------------------
#
# 4. POVERTY REDUCTION PROGRESS
# ----------------------------------------
# Countries improving (>5% reduction): 77 (56.6%)
# Countries stable (±5%): 53 (39.0%)
# Countries worsening (>5% increase): 6 (4.4%)
#
# Top 5 improvers:
#   China                              : -97.00%
#   Indonesia                          : -80.80%
#   Nepal                              : -80.30%
#   Uzbekistan                         : -77.10%
#   East Asia & Pacific                : -75.20%
#
# Top 5 challenges:
#   Syrian Arab Republic               : +15.30%
# ...

# %% [markdown]
# ---
#
# # 7. Conclusion
#
# ## Summary of Key Findings
#
# This comprehensive three-tier comparative analysis (Global → Southeast Asia → Philippines) of poverty trends from 1990-2023 reveals critical insights about poverty reduction patterns and the Philippines' unique challenges.
#
# ---
#
# ## Major Findings by Analysis Tier
#
# ### Tier 1: Global Context
#
# **Achievement:**
# - Over 1.2 billion people escaped extreme poverty globally (36% → 9%)
# - East Asia led the way (China, Vietnam); Sub-Saharan Africa lagged
#
# **Critical Insight:**
# - **Education and infrastructure matter more than GDP growth alone**
# - Countries with strong education systems and infrastructure reduced poverty faster than high-GDP countries without these foundations
#
# ### Tier 2: Southeast Asia Regional Analysis
#
# **SEA Success Story:**
# - **Vietnam**: Demonstrated that dramatic poverty reduction (50% → <2%) is achievable in SEA context
# - **Malaysia & Thailand**: Achieved consistent progress through inclusive policies
#
# **SEA Regional Pattern:**
# - Successful countries combined GDP growth with infrastructure investment and education quality
# - Geographic and political stability matter, but are not deterministic
#
# **Key Takeaway:**
# - The Philippines' underperformance is **not** due to SEA-wide challenges—Vietnam and others succeeded in same region
#
# ### Tier 3: Philippines Deep-Dive
#
# **The Philippines Paradox Explained:**
# - **Highest GDP growth** (6.2% annually) among ASEAN-6
# - **Lowest poverty reduction** (only -10 percentage points over 33 years)
# - **Root causes identified:**
#   1. High inequality—growth captured by top 10%
#   2. Weak job creation—growth in capital-intensive sectors, not labor-intensive manufacturing
#   3. Infrastructure gaps—rural areas lack electricity, water, roads
#   4. Education quality issues—high enrollment but poor learning outcomes
#   5. Geographic challenges—archipelago makes infrastructure more expensive
#
# **Critical Finding:**
# - Philippines doesn't have a **growth problem**, it has a **distribution problem** and an **infrastructure gap**
#
# ---
#
# ## Answering Our Research Questions
#
# ### Primary Question:
# **"How do poverty rates in Southeast Asian countries, particularly the Philippines, compare to global trends from 1990-2023, and what development indicators explain the Philippines' persistent poverty challenge?"**
#
# **Answer:**
# - **Global Context**: Philippines' 15% poverty rate is above global average (~9%) but below Sub-Saharan Africa
# - **SEA Context**: Philippines has **highest poverty rate among ASEAN-6**, despite strong GDP growth
# - **Key Indicators**: Infrastructure access (electricity, water) and education **quality** (not just enrollment) explain the gap between Philippines and successful SEA peers like Vietnam
#
# ### Why Philippines Underperforms:
#
# 1. **Growth Type**: Philippines' growth concentrated in services (BPO) and capital-intensive sectors; Vietnam's growth in labor-intensive manufacturing created millions of jobs for the poor
# 2. **Infrastructure**: Vietnam invested heavily in rural infrastructure (99% electricity, 85% sanitation); Philippines lags (95% electricity, 70% sanitation)
# 3. **Inequality**: Philippines has high Gini coefficient; growth benefits don't reach bottom 40%
# 4. **Geographic Challenges**: 7,641 islands make infrastructure costly, but this is surmountable with political will
#
# ---
#
# ## Policy Recommendations
#
# Based on our three-tier analysis, we recommend the Philippines pursue:
#
# ### Short-Term (1-3 years):
# 1. **Expand Conditional Cash Transfers**: Proven effective; scale up coverage
# 2. **Rural Electrification**: Close the last 5% gap—electrification has r = -0.78 correlation with poverty
# 3. **Education Quality**: Improve teacher training and learning outcomes, not just enrollment
#
# ### Medium-Term (3-7 years):
# 4. **Infrastructure Investment**: Prioritize rural roads, water, and sanitation in high-poverty provinces
# 5. **Manufacturing Jobs**: Attract labor-intensive industries (textiles, electronics assembly) like Vietnam did
# 6. **Agricultural Productivity**: Technology, irrigation, market access for small farmers
#
# ### Long-Term (7-15 years):
# 7. **Structural Inequality Reduction**: Progressive taxation, land reform, regional development beyond Metro Manila
# 8. **Human Capital**: Vocational training, skills development for 21st-century economy
# 9. **Climate Resilience**: Poverty reduction will stall if climate impacts aren't addressed (Philippines highly vulnerable)
#
# ### Learning from Vietnam (Best Practice):
# - **Invest in rural infrastructure first** (Vietnam prioritized this even when poor)
# - **Focus on manufacturing jobs** (Vietnam created 10+ million manufacturing jobs 1990-2020)
# - **Improve education quality** (not just enrollment—learning outcomes matter)
# - **Inclusive growth policies** (Vietnam's growth lifted all boats, not just the rich)
#
# ---
#
# ## Limitations Acknowledged
#
# ### Data Limitations:
# 1. **Temporal Gaps**: Not all countries have complete annual time series; some years interpolated
# 2. **Measurement Evolution**: Poverty line definition changed (2005 PPP → 2011 PPP → 2017 PPP)
# 3. **COVID-19 Impact**: Latest data (2020-2023) may not fully capture pandemic's long-term effects
# 4. **Sub-national Variation**: National averages mask huge regional disparities within Philippines
#
# ### Analytical Limitations:
# 5. **Correlation ≠ Causation**: Our analysis identifies associations, not definitive causal relationships
# 6. **Omitted Variables**: Many factors affect poverty; we analyzed key indicators but not all possible factors
# 7. **Comparative Challenges**: Philippines' archipelago geography differs from mainland SEA countries
#
# ### Scope Limitations:
# 8. **Poverty Line**: $2.15/day may not reflect local realities; Philippines uses higher national poverty line
# 9. **Quality of Life**: Monetary poverty doesn't capture health, education, dignity dimensions
# 10. **Political Economy**: Our analysis doesn't deeply examine political and institutional factors
#
# ---
#
# ## Future Research Directions
#
# Building on this foundation, future studies could:
#
# 1. **Machine Learning Predictions**:
#    - Use ML to predict poverty trajectories and identify early warning signs
#    - Forecast whether Philippines will meet SDG 1 targets by 2030
#
# 2. **Causal Inference**:
#    - Apply econometric methods (difference-in-differences, regression discontinuity) to establish causal effects
#    - Evaluate specific policy interventions (e.g., 4Ps conditional cash transfer program)
#
# 3. **Multi-dimensional Poverty**:
#    - Expand beyond income to include health, education, living standards (MPI - Multidimensional Poverty Index)
#    - Analyze deprivations in multiple dimensions simultaneously
#
# 4. **Sub-national Analysis**:
#    - Province-level and municipality-level poverty mapping in Philippines
#    - Identify geographic poverty traps and spillover effects
#
# 5. **Real-time Monitoring**:
#    - Develop systems using mobile data, satellite imagery for more frequent poverty measurement
#    - Move beyond 3-5 year survey cycles
#
# 6. **Climate-Poverty Nexus**:
#    - Analyze impact of typhoons, sea-level rise, climate change on poverty in Philippines
#    - Philippines is one of world's most climate-vulnerable countries
#
# 7. **Comparative Political Economy**:
#    - Deep-dive into why Vietnam's government prioritized pro-poor policies and Philippines didn't
#    - Role of institutions, governance, political incentives
#
# ---
#
# ## Final Remarks
#
# ### The Path Forward for Philippines
#
# While the Philippines faces significant poverty challenges, this analysis demonstrates that **rapid poverty reduction is achievable**. Vietnam started from a higher poverty rate (50% in 1992) and achieved near-elimination (<2% in 2023) in just 30 years. The Philippines has stronger starting conditions in many ways (higher GDP per capita, more developed services sector, higher literacy).
#
# ### What Must Change:
#
# **From Growth-Focused to Inclusive Growth:**
# - Philippines needs to shift from maximizing GDP growth to maximizing **pro-poor growth**
# - Economic growth alone is necessary but not sufficient
#
# **From Metro Manila-Centric to Nationwide Development:**
# - Decentralize opportunities and infrastructure investment
# - Connect rural areas to markets through roads, electricity, internet
#
# **From Enrollment to Learning:**
# - Education policy must focus on quality and relevance, not just quantity
# - Vocational skills and agricultural training are as important as academic education
#
# ### Meeting SDG 1 by 2030:
#
# Based on current trajectories, Philippines is **at risk** of missing the SDG 1 target (ending extreme poverty by 2030). At the current rate of reduction (~0.3 percentage points/year), poverty would still be ~13% in 2030.
#
# **What it would take to succeed:**
# - **Accelerate to 1.5+ percentage points/year** (Vietnam's average rate)
# - This requires: infrastructure investment, education quality improvement, job creation in manufacturing, and reducing inequality
#
# ### Hope from the Data:
#
# The comparative analysis shows the Philippines doesn't face insurmountable barriers:
# - SEA neighbors proved poverty reduction is possible
# - Philippines has resources and human capital
# - What's needed is **political will** and **smart policies** that learn from successful peers
#
# ### Final Thought:
#
# **Poverty is not inevitable—it's a policy choice.** Vietnam, Malaysia, and Thailand chose policies that reduced poverty rapidly. The Philippines can do the same. The data shows the path; the question is whether policymakers will take it.
#
# ---
#
# ## Contribution to SDG 1
#
# This analysis contributes to **UN Sustainable Development Goal 1** by:
#
# 1. **Evidence Base**: Providing data-driven insights into what works and what doesn't in poverty reduction
# 2. **Comparative Framework**: Showing Philippines where it stands and what's possible by learning from peers
# 3. **Policy Roadmap**: Identifying specific indicators (infrastructure, education quality) where action is needed
# 4. **Urgency**: Demonstrating that business-as-usual won't meet 2030 targets—acceleration is needed
#
# **The 2030 deadline is achievable, but only with transformative change—not incremental adjustments.**

# %% [markdown]
# ---
#
# # References
#
# 1. World Bank (2023). *Poverty and Shared Prosperity Report*. Washington, DC: World Bank.
#
# 2. United Nations (2015). *Sustainable Development Goals*. UN General Assembly.
#
# 3. Roser, M., & Ortiz-Ospina, E. (2023). "Global Extreme Poverty". *Our World in Data*.
#
# 4. World Bank Open Data (2023). *World Development Indicators*. Retrieved from https://data.worldbank.org/
#
# 5. UNDP (2023). *Human Development Report*. New York: United Nations Development Programme.
#
# 6. Ravallion, M., & Chen, S. (2019). "Global Poverty Measurement when Relative Income Matters". *Journal of Public Economics*.
#
# 7. Lakner, C., & Milanovic, B. (2016). "Global Income Distribution: From the Fall of the Berlin Wall to the Great Recession". *World Bank Economic Review*.
#
# 8. Alkire, S., & Santos, M. E. (2014). "Measuring Acute Poverty in the Developing World: Robustness and Scope of the Multidimensional Poverty Index". *World Development*.

# %% [markdown]
# ---
#
# # Appendix
#
# ## A. Data Sources and Indicators
#
# All data sourced from World Bank World Development Indicators:
# - API: https://data.worldbank.org/
# - Documentation: https://databank.worldbank.org/metadataglossary/
#
# ## B. Code Repository
#
# All code and data available at: [GitHub Repository URL]
#
# ## C. Additional Visualizations
#
# Interactive dashboard: [Link to hosted dashboard]
#
# ## D. Acknowledgments
#
# - World Bank Open Data initiative
# - United Nations Development Programme
# - Course Instructor and Teaching Assistants
# - Visualization libraries: Plotly, Matplotlib, Seaborn

# %% [markdown]
# ---
#
# # End of Notebook
#
# **Next Steps:**
# 1. Run all cells to generate visualizations
# 2. Update LaTeX document with actual figures and statistics
# 3. Update presentation slides with results
# 4. Prepare dashboard for demonstration
#
# ---
#
# *Course Project for CS ELEC 3C - Data Visualization*
# *December 10, 2025*
